# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  Data collection using free stock API.
#
# # Register here: https://financialmodelingprep.com/login   and create API Key

# %%
# Other libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from urllib.request import urlopen

# %%
#piford_key = 'e0c8820624abede12b92380ba5147ace'
#https://financialmodelingprep.com/api/v3/profile/AAPL?apikey=e0c8820624abede12b92380ba5147ace

#sym='AAPL'
#sym=['TWTR','FB','MSFT','NVDA','AAPL','CRM']
#url = "https://financialmodelingprep.com/api/v3/company/profile/"+str(sym)+'?apikey='+piford_key
#response = urlopen(url)
#data = response.read().decode("utf-8")
#profile = json.loads(data)

# %%
#profile

# %% [markdown]
# # url for getting data of multiple companies

# %%
url = "https://financialmodelingprep.com/api/v3/company/profile/AAPL,CRM,NVDA"+'?apikey='+key
response = urlopen(url)
data = response.read().decode("utf-8")
profile = json.loads(data)

# %%
profile
# Out:
# {'companyProfiles': [{'symbol': 'AAPL',
#    'profile': {'price': 112.28,
#     'beta': '1.34679',
#     'volAvg': '172504452',
#     'mktCap': '1.92026863E12',
#     'lastDiv': '0.75',
#     'range': '53.1525-137.98',
#     'changes': 4.06,
#     'changesPercentage': '(+3.75%)',
#     'companyName': 'Apple Inc',
#     'exchange': 'Nasdaq Global Select',
#     'exchangeShortName': 'NASDAQ',
#     'industry': 'Consumer Electronics',
#     'website': 'https://www.apple.com/',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Analyse Book value per share

# %%
plt.figure(figsize=(10,4))
plt.title("Book Value per Share",fontsize=18)
plt.bar(x=df1['companyName'],height=df1['price'],color='orange',edgecolor='k')
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=14)
plt.ylabel('Price',fontsize=16)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Debt to Equity Ratio:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,4))
plt.title("debtEquityRatio",fontsize=18)
plt.bar(x=df1['companyName'],height=df1['debtEquityRatio'])
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=14)
plt.ylabel("debtEquityRatio",fontsize=16)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Only companies with market cap > 200 billion USD
df_large_cap = df1[df1['Market Cap']>200e9]
df_large_cap[['companyName','Market Cap']]
